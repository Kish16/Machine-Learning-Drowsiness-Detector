# %%
# !pip install torch torchvision torchaudio
# Out:
# ...
#   Using cached torch-1.13.1-cp39-cp39-win_amd64.whl (162.5 MB)
# ...
#   Using cached torchvision-0.14.1-cp39-cp39-win_amd64.whl (1.1 MB)
# ...
#   Using cached torchaudio-0.13.1-cp39-cp39-win_amd64.whl (2.0 MB)
# ...

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# ...
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
# ...
#      ---------------------------------------- 1.1/1.1 MB 9.9 MB/s eta 0:00:00
# ...
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached tensorboard_data_server-0.7.0-py3-none-any.whl (2.4 kB)
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#   Using cached grpcio-1.51.3-cp39-cp39-win_amd64.whl (3.7 MB)
# ...
#   Using cached google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
# ...
#      ------------------------------------- 420.6/420.6 kB 13.2 MB/s eta 0:00:00
# ...
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\kisha/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-3-5 Python-3.9.13 torch-1.13.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img = 'https://media.cntraveler.com/photos/53e2f41cdddaa35c30f66775/master/pass/highway-traffic.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 768x1024 14 persons, 34 cars, 1 motorcycle, 1 truck
# Speed: 726.3ms pre-process, 750.8ms inference, 35.9ms NMS per image at shape (1, 3, 480, 640)

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
results.xyxy
# Out:
# [tensor([[6.40654e+02, 4.36777e+02, 8.52050e+02, 5.97026e+02, 9.15720e-01, 2.00000e+00],
#          [8.33523e+02, 5.21313e+02, 1.02400e+03, 7.19699e+02, 9.00862e-01, 2.00000e+00],
#          [3.43307e+02, 5.18850e+02, 5.85849e+02, 6.91249e+02, 8.62562e-01, 2.00000e+00],
#          [9.14413e+02, 3.68110e+02, 1.02391e+03, 5.00440e+02, 8.54357e-01, 2.00000e+00],
#          [8.78348e+02, 1.18899e+02, 1.01428e+03, 1.98658e+02, 8.18422e-01, 2.00000e+00],
#          [2.27464e+02, 1.04710e+02, 3.82018e+02, 2.33567e+02, 8.15981e-01, 2.00000e+00],
#          [8.56832e+02, 2.97138e+02, 1.02240e+03, 4.35603e+02, 8.09992e-01, 2.00000e+00],
#          [2.59227e+02, 3.89023e+02, 4.75313e+02, 5.84724e+02, 8.05433e-01, 2.00000e+00],
#          [9.80210e+02, 1.48539e+02, 1.02400e+03, 2.37785e+02, 8.01399e-01, 2.00000e+00],
#          [5.82040e+02, 3.39581e+02, 7.80498e+02, 5.12379e+02, 7.85629e-01, 2.00000e+00],
# ...

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    #Make detections
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid #Unique identifier for images
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #data/images folder path 
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
#Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    #Loop through images range
    for img_num in range(number_imgs):
        print('Collecting images for {}, images number{}'.format(label, img_num))
        
        #Webcam feed
        ret, frame = cap.read()
        
        #Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        #Writes out image to file
        cv2.imwrite(imgname, frame)
        
        #Render to the screen
        cv2.imshow('Image Collection', frame)
        
        #2 second delay between captures for time spacing between captures
        time.sleep(2)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, images number{}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.03798386-bc2d-11ed-bb5c-34c93d56b25f.jpg
# ...
# data\images\awake.03798387-bc2d-11ed-a54d-34c93d56b25f.jpg
# ...
# data\images\awake.03798388-bc2d-11ed-ba19-34c93d56b25f.jpg
# ...
# data\images\awake.03798389-bc2d-11ed-9412-34c93d56b25f.jpg
# ...
# data\images\awake.0379838a-bc2d-11ed-a7ce-34c93d56b25f.jpg
# ...
# data\images\awake.0379838b-bc2d-11ed-b762-34c93d56b25f.jpg
# ...
# data\images\awake.0379838c-bc2d-11ed-82b4-34c93d56b25f.jpg
# ...
# data\images\awake.0379838d-bc2d-11ed-9c6f-34c93d56b25f.jpg
# ...
# data\images\awake.0379838e-bc2d-11ed-91e3-34c93d56b25f.jpg
# ...
# data\images\awake.0379838f-bc2d-11ed-a0e0-34c93d56b25f.jpg
# ...
# data\images\awake.03798390-bc2d-11ed-bf1a-34c93d56b25f.jpg
# ...
# data\images\awake.03798391-bc2d-11ed-8882-34c93d56b25f.jpg
# ...
# data\images\awake.03798392-bc2d-11ed-b216-34c93d56b25f.jpg
# ...
# data\images\awake.03799fab-bc2d-11ed-bdfe-34c93d56b25f.jpg
# ...
# data\images\awake.03799fac-bc2d-11ed-a4eb-34c93d56b25f.jpg
# ...
# data\images\awake.03799fad-bc2d-11ed-9bec-34c93d56b25f.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp3/weights/last.pt', force_reload=True)

# %%
img = os.path.join('data','images','awake.3a426ebe-bad1-11ed-a7fe-34c93d56b25f.jpg')

# %%
results = model(img)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
